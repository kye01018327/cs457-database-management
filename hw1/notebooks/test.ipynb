# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
r
# Out:
# <Response [200]>

# %%
r = requests.post('https://httpbin.org/post', data={'key': 'value'})
r
# Out:
# <Response [200]>

# %%
r = requests.put('https://httpbin.org/put', data={'key': 'value'})
print(r.url)
r = requests.delete('https://httpbin.org/delete')
print(r.url)
r = requests.head('https://httpbin.org/get')
print(r.url)
r = requests.options('https://httpbin.org/get')
print(r.url)
# Out:
# https://httpbin.org/put
# https://httpbin.org/delete
# https://httpbin.org/get
# https://httpbin.org/get

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)
r.url
# Out:
# 'https://httpbin.org/get?key1=value1&key2=value2'

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}

r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %% [markdown]
# Response Content

# %%
r = requests.get('https://api.github.com/events')
data = r.json()
for element in data:
    print(element)
# Out:
# {'id': '54048487966', 'type': 'PushEvent', 'actor': {'id': 109941110, 'login': 'kompl3xpr', 'display_login': 'kompl3xpr', 'gravatar_id': '', 'url': 'https://api.github.com/users/kompl3xpr', 'avatar_url': 'https://avatars.githubusercontent.com/u/109941110?'}, 'repo': {'id': 1047299620, 'name': 'kompl3xpr/wplace_monitor_py', 'url': 'https://api.github.com/repos/kompl3xpr/wplace_monitor_py'}, 'payload': {'repository_id': 1047299620, 'push_id': 26484382552, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '9b56c66a8b1fbd83a1a91967c635061e8885f793', 'before': 'e89bff26931efe51879f8c8a4409518e3bfb0d09', 'commits': [{'sha': '9b56c66a8b1fbd83a1a91967c635061e8885f793', 'author': {'email': 'kompl3xpr@proton.me', 'name': 'kompl3xpr'}, 'message': 'update all singletons', 'distinct': True, 'url': 'https://api.github.com/repos/kompl3xpr/wplace_monitor_py/commits/9b56c66a8b1fbd83a1a91967c635061e8885f793'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487969', 'type': 'CreateEvent', 'actor': {'id': 51323744, 'login': 'coco-coc', 'display_login': 'coco-coc', 'gravatar_id': '', 'url': 'https://api.github.com/users/coco-coc', 'avatar_url': 'https://avatars.githubusercontent.com/u/51323744?'}, 'repo': {'id': 1047635339, 'name': 'coco-coc/Brave', 'url': 'https://api.github.com/repos/coco-coc/Brave'}, 'payload': {'ref': 'v0.70.75', 'ref_type': 'tag', 'master_branch': 'main', 'description': None, 'pusher_type': 'user'}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487964', 'type': 'CommitCommentEvent', 'actor': {'id': 54239794, 'login': 'animesh-banik', 'display_login': 'animesh-banik', 'gravatar_id': '', 'url': 'https://api.github.com/users/animesh-banik', 'avatar_url': 'https://avatars.githubusercontent.com/u/54239794?'}, 'repo': {'id': 1041597817, 'name': 'animesh-banik/DataScienceProject_Databriks', 'url': 'https://api.github.com/repos/animesh-banik/DataScienceProject_Databriks'}, 'payload': {'comment': {'url': 'https://api.github.com/repos/animesh-banik/DataScienceProject_Databriks/comments/164895478', 'html_url': 'https://github.com/animesh-banik/DataScienceProject_Databriks/commit/f9f1cc0bc5a39a3ce0eb7fe300fbdb3943338847#r164895478', 'id': 164895478, 'node_id': 'CC_kwDOPhWFec4J1Br2', 'user': {'login': 'animesh-banik', 'id': 54239794, 'node_id': 'MDQ6VXNlcjU0MjM5Nzk0', 'avatar_url': 'https://avatars.githubusercontent.com/u/54239794?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/animesh-banik', 'html_url': 'https://github.com/animesh-banik', 'followers_url': 'https://api.github.com/users/animesh-banik/followers', 'following_url': 'https://api.github.com/users/animesh-banik/following{/other_user}', 'gists_url': 'https://api.github.com/users/animesh-banik/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/animesh-banik/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/animesh-banik/subscriptions', 'organizations_url': 'https://api.github.com/users/animesh-banik/orgs', 'repos_url': 'https://api.github.com/users/animesh-banik/repos', 'events_url': 'https://api.github.com/users/animesh-banik/events{/privacy}', 'received_events_url': 'https://api.github.com/users/animesh-banik/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'position': 14, 'line': None, 'path': 'Python Code/Python Programming.ipynb', 'commit_id': 'f9f1cc0bc5a39a3ce0eb7fe300fbdb3943338847', 'created_at': '2025-08-31T04:29:35Z', 'updated_at': '2025-08-31T04:29:35Z', 'author_association': 'OWNER', 'body': 'Updated', 'reactions': {'url': 'https://api.github.com/repos/animesh-banik/DataScienceProject_Databriks/comments/164895478/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}}}, 'public': True, 'created_at': '2025-08-31T04:29:35Z'}
# {'id': '54048487951', 'type': 'PullRequestEvent', 'actor': {'id': 37933096, 'login': 'r-ryantm', 'display_login': 'r-ryantm', 'gravatar_id': '', 'url': 'https://api.github.com/users/r-ryantm', 'avatar_url': 'https://avatars.githubusercontent.com/u/37933096?'}, 'repo': {'id': 4542716, 'name': 'NixOS/nixpkgs', 'url': 'https://api.github.com/repos/NixOS/nixpkgs'}, 'payload': {'action': 'opened', 'number': 438798, 'pull_request': {'url': 'https://api.github.com/repos/NixOS/nixpkgs/pulls/438798', 'id': 2787344602, 'node_id': 'PR_kwDOAEVQ_M6mI4Da', 'html_url': 'https://github.com/NixOS/nixpkgs/pull/438798', 'diff_url': 'https://github.com/NixOS/nixpkgs/pull/438798.diff', 'patch_url': 'https://github.com/NixOS/nixpkgs/pull/438798.patch', 'issue_url': 'https://api.github.com/repos/NixOS/nixpkgs/issues/438798', 'number': 438798, 'state': 'open', 'locked': False, 'title': 'rednotebook: 2.39 -> 2.41', 'user': {'login': 'r-ryantm', 'id': 37933096, 'node_id': 'MDQ6VXNlcjM3OTMzMDk2', 'avatar_url': 'https://avatars.githubusercontent.com/u/37933096?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/r-ryantm', 'html_url': 'https://github.com/r-ryantm', 'followers_url': 'https://api.github.com/users/r-ryantm/followers', 'following_url': 'https://api.github.com/users/r-ryantm/following{/other_user}', 'gists_url': 'https://api.github.com/users/r-ryantm/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/r-ryantm/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/r-ryantm/subscriptions', 'organizations_url': 'https://api.github.com/users/r-ryantm/orgs', 'repos_url': 'https://api.github.com/users/r-ryantm/repos', 'events_url': 'https://api.github.com/users/r-ryantm/events{/privacy}', 'received_events_url': 'https://api.github.com/users/r-ryantm/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': "Automatic update generated by [nixpkgs-update](https://github.com/ryantm/nixpkgs-update) tools. This update was made based on information from passthru.updateScript.\n\n\nmeta.description for rednotebook is: Modern journal that includes a calendar navigation, customizable templates, export functionality and word clouds\n\nmeta.homepage for rednotebook is: https://rednotebook.sourceforge.io/\n\nmeta.changelog for rednotebook is: https://github.com/jendrikseipp/rednotebook/blob/v2.41/CHANGELOG.md\n\n\n###### Updates performed\n- Ran passthru.UpdateScript\n\n###### To inspect upstream changes\n\n\n\n\n\n###### Impact\n\n<b>Checks done</b>\n\n---\n\n- built on NixOS\n- The tests defined in `passthru.tests`, if any, passed\n- found 2.41 with grep in /nix/store/7yqs0w7a70dzy4ickk02jm44ysanzcsh-rednotebook-2.41\n- found 2.41 in filename of file in /nix/store/7yqs0w7a70dzy4ickk02jm44ysanzcsh-rednotebook-2.41\n\n---\n\n<details>\n<summary>\n<b>Rebuild report</b> (if merged into master) (click to expand)\n</summary>\n\n```\n2 total rebuild path(s)\n\n2 package rebuild(s)\n\nFirst fifty rebuilds by attrpath\n\nrednotebook\n```\n\n</details>\n\n<details>\n<summary>\n<b>Instructions to test this update</b> (click to expand)\n</summary>\n\n---\n\nEither **download from the cache**:\n```\nnix-store -r /nix/store/7yqs0w7a70dzy4ickk02jm44ysanzcsh-rednotebook-2.41 \\\n  --option binary-caches 'https://cache.nixos.org/ https://nixpkgs-update-cache.nix-community.org/' \\\n  --option trusted-public-keys '\n  nixpkgs-update-cache.nix-community.org-1:U8d6wiQecHUPJFSqHN9GSSmNkmdiFW7GW7WNAnHW0SM=\n  cache.nixos.org-1:6NCHdD59X431o0gWypbMrAURkbJ16ZPMQFGspcDShjY=\n  '\n```\n(The nixpkgs-update cache is only trusted for this store-path realization.)\nFor the cached download to work, your user must be in the `trusted-users` list or you can use `sudo` since root is effectively trusted.\n\nOr, **build yourself**:\n```\nnix-build -A rednotebook https://github.com/r-ryantm/nixpkgs/archive/406224595af8b599bb5e7a061f10f47db3567e83.tar.gz\n```\nOr:\n```\nnix build github:r-ryantm/nixpkgs/406224595af8b599bb ...
# {'id': '54048487956', 'type': 'PushEvent', 'actor': {'id': 9559725, 'login': 'cjchandler', 'display_login': 'cjchandler', 'gravatar_id': '', 'url': 'https://api.github.com/users/cjchandler', 'avatar_url': 'https://avatars.githubusercontent.com/u/9559725?'}, 'repo': {'id': 904381792, 'name': 'cjchandler/last_update_repo', 'url': 'https://api.github.com/repos/cjchandler/last_update_repo'}, 'payload': {'repository_id': 904381792, 'push_id': 26484382553, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '2b1f3fa4272dec922ce36f0aee7a9dd615e793a0', 'before': '43c81c20a793ae07a70866c3f43b3801d3922115', 'commits': [{'sha': '2b1f3fa4272dec922ce36f0aee7a9dd615e793a0', 'author': {'email': 'carljosephchandler@gmail.com', 'name': 'cjchandler'}, 'message': 'auto', 'distinct': True, 'url': 'https://api.github.com/repos/cjchandler/last_update_repo/commits/2b1f3fa4272dec922ce36f0aee7a9dd615e793a0'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487952', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 299564229, 'name': 'ohjuntaek/ohjuntaek', 'url': 'https://api.github.com/repos/ohjuntaek/ohjuntaek'}, 'payload': {'repository_id': 299564229, 'push_id': 26484382544, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '3a89671721156d470e1ea8bcada803ea636d7be2', 'before': 'f1bd4497dfb2d09d5e9e8e05290c907f89588f4e', 'commits': [{'sha': '3a89671721156d470e1ea8bcada803ea636d7be2', 'author': {'email': 'action@github.com', 'name': 'GitHub Action'}, 'message': 'Update README', 'distinct': True, 'url': 'https://api.github.com/repos/ohjuntaek/ohjuntaek/commits/3a89671721156d470e1ea8bcada803ea636d7be2'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487948', 'type': 'IssuesEvent', 'actor': {'id': 2107572, 'login': 'mattbaya', 'display_login': 'mattbaya', 'gravatar_id': '', 'url': 'https://api.github.com/users/mattbaya', 'avatar_url': 'https://avatars.githubusercontent.com/u/2107572?'}, 'repo': {'id': 1047602975, 'name': 'mattbaya/media-library-manager', 'url': 'https://api.github.com/repos/mattbaya/media-library-manager'}, 'payload': {'action': 'closed', 'issue': {'url': 'https://api.github.com/repos/mattbaya/media-library-manager/issues/28', 'repository_url': 'https://api.github.com/repos/mattbaya/media-library-manager', 'labels_url': 'https://api.github.com/repos/mattbaya/media-library-manager/issues/28/labels{/name}', 'comments_url': 'https://api.github.com/repos/mattbaya/media-library-manager/issues/28/comments', 'events_url': 'https://api.github.com/repos/mattbaya/media-library-manager/issues/28/events', 'html_url': 'https://github.com/mattbaya/media-library-manager/issues/28', 'id': 3369634550, 'node_id': 'I_kwDOPnEnH87I2Ir2', 'number': 28, 'title': 'Configuration and Environment Variable Security Issues', 'user': {'login': 'mattbaya', 'id': 2107572, 'node_id': 'MDQ6VXNlcjIxMDc1NzI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/2107572?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mattbaya', 'html_url': 'https://github.com/mattbaya', 'followers_url': 'https://api.github.com/users/mattbaya/followers', 'following_url': 'https://api.github.com/users/mattbaya/following{/other_user}', 'gists_url': 'https://api.github.com/users/mattbaya/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mattbaya/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mattbaya/subscriptions', 'organizations_url': 'https://api.github.com/users/mattbaya/orgs', 'repos_url': 'https://api.github.com/users/mattbaya/repos', 'events_url': 'https://api.github.com/users/mattbaya/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mattbaya/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'closed', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2025-08-31T00:51:52Z', 'updated_at': '2025-08-31T04:29:35Z', 'closed_at': '2025-08-31T04:29:35Z', 'author_association': 'OWNER', 'active_lock_reason': None, 'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0}, 'issue_dependencies_summary': {'blocked_by': 0, 'total_blocked_by': 0, 'blocking': 0, 'total_blocking': 0}, 'body': '**Security Issue: Insecure Configuration and Environment Handling**\n\n**Severity:** Medium\n\n**Description:** \nThe application lacks secure configuration management and environment variable handling.\n\n**Configuration Security Issues:**\n\n1. **Hardcoded Sensitive Paths:**\n   - Base path hardcoded: `/Volumes/media/Video`\n   - No environment variable support for configuration\n   - No config file validation\n\n2. **No Environment Isolation:**\n   - Inherits all parent environment variables\n   - No sanitization of environment\n   - Potential for environment variable injection\n\n3. **Missing Configuration Validation:**\n   - No validation of base_path parameter\n   - No check if directories are writable/readable\n   - No validation of external tool paths (ffmpeg, rclone)\n\n**Potential Environment Attacks:**\n\n1. **PATH Manipulation:**\n   ```bash\n   # Attacker modifies PATH to point to malicious binaries\n   export PATH="/tmp/evil:/Users/mjb9/.local/bin:/Users/mjb9/.opencode/bin:/Users/mjb9/.local/bin:/Users/mjb9/.npm-global/bin:/usr/local/anaconda3/bin:/usr/local/anaconda3/condabin:/usr/local/opt/php/bin:/usr/local/opt/whois/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appl ...
# {'id': '54048487945', 'type': 'PushEvent', 'actor': {'id': 50673670, 'login': 'mend-for-github-com[bot]', 'display_login': 'mend-for-github-com', 'gravatar_id': '', 'url': 'https://api.github.com/users/mend-for-github-com[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/50673670?'}, 'repo': {'id': 334004988, 'name': 'MValle21/ts-components', 'url': 'https://api.github.com/repos/MValle21/ts-components'}, 'payload': {'repository_id': 334004988, 'push_id': 26484382572, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/whitesource-remediate/babel-preset-env-7.x-lockfile', 'head': 'cbdf297b1b58d6777c297f994509121129b8071a', 'before': '4194d6ee3e7d193fd6999e74297d06c77a54ef5d', 'commits': [{'sha': 'cbdf297b1b58d6777c297f994509121129b8071a', 'author': {'email': '50673670+mend-for-github-com[bot]@users.noreply.github.com', 'name': 'mend-for-github-com[bot]'}, 'message': 'Update dependency @babel/preset-env to v7.12.13', 'distinct': True, 'url': 'https://api.github.com/repos/MValle21/ts-components/commits/cbdf297b1b58d6777c297f994509121129b8071a'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487937', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 1035979889, 'name': 'CryoYohan/_gauto-cryo-ver', 'url': 'https://api.github.com/repos/CryoYohan/_gauto-cryo-ver'}, 'payload': {'repository_id': 1035979889, 'push_id': 26484382558, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'e9500f2733cca3882aee365431b928661abec3ac', 'before': 'bfb5aea1b593deb1cac2e0b71db19c244e409dab', 'commits': [{'sha': 'e9500f2733cca3882aee365431b928661abec3ac', 'author': {'email': 'cyrilypil@gmail.com', 'name': 'CryoYohan'}, 'message': 'Automated commit #1204798', 'distinct': True, 'url': 'https://api.github.com/repos/CryoYohan/_gauto-cryo-ver/commits/e9500f2733cca3882aee365431b928661abec3ac'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487941', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 406313986, 'name': 'JohnStyleZ/McIce_live', 'url': 'https://api.github.com/repos/JohnStyleZ/McIce_live'}, 'payload': {'repository_id': 406313986, 'push_id': 26484382541, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'c747d2b6ca009150df77a454eb25253beec41382', 'before': 'edf62a1629dccefc57fed0b7f9ddd747fa75ac6d', 'commits': [{'sha': 'c747d2b6ca009150df77a454eb25253beec41382', 'author': {'email': 'actions@users.noreply.github.com', 'name': 'Archive'}, 'message': 'Archive from Sun Aug 31 04:29:34 UTC 2025', 'distinct': True, 'url': 'https://api.github.com/repos/JohnStyleZ/McIce_live/commits/c747d2b6ca009150df77a454eb25253beec41382'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487942', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 871113901, 'name': 'iamnotyourspy/iamnotyourspy.github.io', 'url': 'https://api.github.com/repos/iamnotyourspy/iamnotyourspy.github.io'}, 'payload': {'repository_id': 871113901, 'push_id': 26484382563, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '298fdc8ac229ddd3cb35ed6cdb913735d1f1a6fc', 'before': '891a4296092c97e81c6466a3e39e7b191402c9b4', 'commits': [{'sha': '298fdc8ac229ddd3cb35ed6cdb913735d1f1a6fc', 'author': {'email': 'iamnotyourspy@gmail.com', 'name': 'iamnotyourspy'}, 'message': 'github workflows auto update data', 'distinct': True, 'url': 'https://api.github.com/repos/iamnotyourspy/iamnotyourspy.github.io/commits/298fdc8ac229ddd3cb35ed6cdb913735d1f1a6fc'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487936', 'type': 'PushEvent', 'actor': {'id': 62788726, 'login': 'hydang99', 'display_login': 'hydang99', 'gravatar_id': '', 'url': 'https://api.github.com/users/hydang99', 'avatar_url': 'https://avatars.githubusercontent.com/u/62788726?'}, 'repo': {'id': 1047636449, 'name': 'hydang99/note_translate', 'url': 'https://api.github.com/repos/hydang99/note_translate'}, 'payload': {'repository_id': 1047636449, 'push_id': 26484382573, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'dfd02d57b58a85ced683ad2276343b765984dbe3', 'before': '4422bfa220b8eb3f17373bf5da8decdef69ebff4', 'commits': [{'sha': 'dfd02d57b58a85ced683ad2276343b765984dbe3', 'author': {'email': 'hydang.cs99@gmail.com', 'name': 'Hy Dang'}, 'message': 'Completely rewrite Dockerfile with detailed startup script\n\n- Create explicit startup script with echo statements\n- Add detailed logging at each step\n- Force Railway to rebuild by changing Dockerfile structure\n- This should reveal exactly where the startup is failing', 'distinct': True, 'url': 'https://api.github.com/repos/hydang99/note_translate/commits/dfd02d57b58a85ced683ad2276343b765984dbe3'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487933', 'type': 'PushEvent', 'actor': {'id': 1312412, 'login': 'osmond', 'display_login': 'osmond', 'gravatar_id': '', 'url': 'https://api.github.com/users/osmond', 'avatar_url': 'https://avatars.githubusercontent.com/u/1312412?'}, 'repo': {'id': 1047700586, 'name': 'osmond/flora-science', 'url': 'https://api.github.com/repos/osmond/flora-science'}, 'payload': {'repository_id': 1047700586, 'push_id': 26484382556, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/osmond/polish-plant-detail-page-with-tailwind', 'head': 'b6077a56720c3c1fd7fcc14a687d2eb777d24d11', 'before': 'd259aabb0bd18f5429e52ed6169ac9308444f7fe', 'commits': [{'sha': 'b6077a56720c3c1fd7fcc14a687d2eb777d24d11', 'author': {'email': 'jonathan.osmond@gmail.com', 'name': 'Jon Osmond'}, 'message': 'feat: polish plant detail page layout', 'distinct': True, 'url': 'https://api.github.com/repos/osmond/flora-science/commits/b6077a56720c3c1fd7fcc14a687d2eb777d24d11'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487938', 'type': 'IssueCommentEvent', 'actor': {'id': 185648356, 'login': 'mav-bot[bot]', 'display_login': 'mav-bot', 'gravatar_id': '', 'url': 'https://api.github.com/users/mav-bot[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/185648356?'}, 'repo': {'id': 1044164671, 'name': 'MaverickD650/home-ops', 'url': 'https://api.github.com/repos/MaverickD650/home-ops'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/MaverickD650/home-ops/issues/31', 'repository_url': 'https://api.github.com/repos/MaverickD650/home-ops', 'labels_url': 'https://api.github.com/repos/MaverickD650/home-ops/issues/31/labels{/name}', 'comments_url': 'https://api.github.com/repos/MaverickD650/home-ops/issues/31/comments', 'events_url': 'https://api.github.com/repos/MaverickD650/home-ops/issues/31/events', 'html_url': 'https://github.com/MaverickD650/home-ops/pull/31', 'id': 3369793671, 'node_id': 'PR_kwDOPjywP86mI4AU', 'number': 31, 'title': 'chore(flux): update image external-service 16.3.2 → 16.3.4', 'user': {'login': 'renovate[bot]', 'id': 29139614, 'node_id': 'MDM6Qm90MjkxMzk2MTQ=', 'avatar_url': 'https://avatars.githubusercontent.com/in/2740?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/renovate%5Bbot%5D', 'html_url': 'https://github.com/apps/renovate', 'followers_url': 'https://api.github.com/users/renovate%5Bbot%5D/followers', 'following_url': 'https://api.github.com/users/renovate%5Bbot%5D/following{/other_user}', 'gists_url': 'https://api.github.com/users/renovate%5Bbot%5D/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/renovate%5Bbot%5D/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/renovate%5Bbot%5D/subscriptions', 'organizations_url': 'https://api.github.com/users/renovate%5Bbot%5D/orgs', 'repos_url': 'https://api.github.com/users/renovate%5Bbot%5D/repos', 'events_url': 'https://api.github.com/users/renovate%5Bbot%5D/events{/privacy}', 'received_events_url': 'https://api.github.com/users/renovate%5Bbot%5D/received_events', 'type': 'Bot', 'user_view_type': 'public', 'site_admin': False}, 'labels': [{'id': 9171579802, 'node_id': 'LA_kwDOPjywP88AAAACIqszmg', 'url': 'https://api.github.com/repos/MaverickD650/home-ops/labels/type/patch', 'name': 'type/patch', 'color': 'ffec19', 'default': False, 'description': None}, {'id': 9171579803, 'node_id': 'LA_kwDOPjywP88AAAACIqszmw', 'url': 'https://api.github.com/repos/MaverickD650/home-ops/labels/automerge', 'name': 'automerge', 'color': 'ee0701', 'default': False, 'description': None}, {'id': 9171579810, 'node_id': 'LA_kwDOPjywP88AAAACIqszog', 'url': 'https://api.github.com/repos/MaverickD650/home-ops/labels/renovate/container', 'name': 'renovate/container', 'color': '027fa0', 'default': False, 'description': None}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2025-08-31T04:28:55Z', 'updated_at': '2025-08-31T04:29:35Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/MaverickD650/home-ops/pulls/31', 'html_url': 'https://github.com/MaverickD650/home-ops/pull/31', 'diff_url': 'https://github.com/MaverickD650/home-ops/pull/31.diff', 'patch_url': 'https://github.com/MaverickD650/home-ops/pull/31.patch', 'merged_at': None}, 'body': "This PR contains the following updates:\n\n| Package | Update | Change |\n|---|---|---|\n| [external-service](https://truecharts.org/charts/stable/external-service) ([source](https://redirect.github.com/truecharts/charts/tree/HEAD/charts/stable/external-service)) | patch | `16.3.2` -> `16.3.4` |\n\n---\n\n### Configuration\n\n📅 **Schedule**: Branch creation - At any time (no schedule defined), Automerge - At any time (no schedule defined).\n\n🚦 **Automerge**: Enabled.\n\n♻ **Rebasing**: Whenever PR becomes conflicted, or you tick the rebase/retry checkbox.\n\n🔕 **Ignore**: Close this PR an ...
# {'id': '54048487929', 'type': 'PushEvent', 'actor': {'id': 206848837, 'login': 'si2sun', 'display_login': 'si2sun', 'gravatar_id': '', 'url': 'https://api.github.com/users/si2sun', 'avatar_url': 'https://avatars.githubusercontent.com/u/206848837?'}, 'repo': {'id': 1047589516, 'name': 'si2sun/self-webside', 'url': 'https://api.github.com/repos/si2sun/self-webside'}, 'payload': {'repository_id': 1047589516, 'push_id': 26484382565, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'a18fae7df302741f5f46f9ccb441d740b8a6da4c', 'before': '5f3e098a83d562828d9dfddf41fababfc9ce8b7b', 'commits': [{'sha': 'a18fae7df302741f5f46f9ccb441d740b8a6da4c', 'author': {'email': 'lizongyan928@gmail.com', 'name': 'si2sun'}, 'message': 'Update project-opencv.html', 'distinct': True, 'url': 'https://api.github.com/repos/si2sun/self-webside/commits/a18fae7df302741f5f46f9ccb441d740b8a6da4c'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487928', 'type': 'PushEvent', 'actor': {'id': 211022932, 'login': 'Gyan862', 'display_login': 'Gyan862', 'gravatar_id': '', 'url': 'https://api.github.com/users/Gyan862', 'avatar_url': 'https://avatars.githubusercontent.com/u/211022932?'}, 'repo': {'id': 1047601173, 'name': 'Gyan862/s.b.m-english-school', 'url': 'https://api.github.com/repos/Gyan862/s.b.m-english-school'}, 'payload': {'repository_id': 1047601173, 'push_id': 26484382555, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'd86ca36f6174c3d1d8b7c19405d28f28e318f2e7', 'before': 'be86da19a434e1800fe95d0d14266591aa1fbc6f', 'commits': [{'sha': 'd86ca36f6174c3d1d8b7c19405d28f28e318f2e7', 'author': {'email': 'gyanranjankumargupta@gmail.com', 'name': 'Gyan862'}, 'message': 'Update index.html', 'distinct': True, 'url': 'https://api.github.com/repos/Gyan862/s.b.m-english-school/commits/d86ca36f6174c3d1d8b7c19405d28f28e318f2e7'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487923', 'type': 'PushEvent', 'actor': {'id': 47436000, 'login': 'decentaro', 'display_login': 'decentaro', 'gravatar_id': '', 'url': 'https://api.github.com/users/decentaro', 'avatar_url': 'https://avatars.githubusercontent.com/u/47436000?'}, 'repo': {'id': 1047714261, 'name': 'decentaro/portndock', 'url': 'https://api.github.com/repos/decentaro/portndock'}, 'payload': {'repository_id': 1047714261, 'push_id': 26484382546, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '7ad1f92e639940423a70efbda91cdb0e5c8aa8c7', 'before': 'f236dbb1ca80f3ac4a227b0cc786c21a124245eb', 'commits': [{'sha': '7ad1f92e639940423a70efbda91cdb0e5c8aa8c7', 'author': {'email': 'dymarc92@gmail.com', 'name': 'decentaro'}, 'message': "Fix critical port detection bug in ss command\n\n- Fixed malformed ss command that was adding duplicate flags\n- Command was becoming 'ss -tlnp -t' instead of 'ss -tlnp'\n- Now properly detects Docker containers and all listening ports\n- Tested: now finds 14+ sockets including Docker ports 5173, 8000, 6379, 5432", 'distinct': True, 'url': 'https://api.github.com/repos/decentaro/portndock/commits/7ad1f92e639940423a70efbda91cdb0e5c8aa8c7'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487932', 'type': 'WatchEvent', 'actor': {'id': 60874741, 'login': 'adrian539859', 'display_login': 'adrian539859', 'gravatar_id': '', 'url': 'https://api.github.com/users/adrian539859', 'avatar_url': 'https://avatars.githubusercontent.com/u/60874741?'}, 'repo': {'id': 262932920, 'name': '47ng/nuqs', 'url': 'https://api.github.com/repos/47ng/nuqs'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-08-31T04:29:36Z', 'org': {'id': 43356325, 'login': '47ng', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/47ng', 'avatar_url': 'https://avatars.githubusercontent.com/u/43356325?'}}
# {'id': '54048487931', 'type': 'PushEvent', 'actor': {'id': 169187645, 'login': 'hyperyuk', 'display_login': 'hyperyuk', 'gravatar_id': '', 'url': 'https://api.github.com/users/hyperyuk', 'avatar_url': 'https://avatars.githubusercontent.com/u/169187645?'}, 'repo': {'id': 998836996, 'name': 'hyperyuk/database', 'url': 'https://api.github.com/repos/hyperyuk/database'}, 'payload': {'repository_id': 998836996, 'push_id': 26484382561, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'a96e16813d3592ff3c97d2631eaed4cc790ad329', 'before': '16212b579f76cb0b410a97a13a2fcb5a2a30bbdf', 'commits': [{'sha': 'a96e16813d3592ff3c97d2631eaed4cc790ad329', 'author': {'email': 'dikstak1@gmail.com', 'name': 'hyperyuk'}, 'message': 'Update database oleh bot', 'distinct': True, 'url': 'https://api.github.com/repos/hyperyuk/database/commits/a96e16813d3592ff3c97d2631eaed4cc790ad329'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487930', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 479038573, 'name': 'mbmontana785/my-data-robot', 'url': 'https://api.github.com/repos/mbmontana785/my-data-robot'}, 'payload': {'repository_id': 479038573, 'push_id': 26484382545, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'd1b324fa1d02b42d55ea9d8454e9a271ef9a3829', 'before': '3ebec5ff031544abe78388c7f5a2956fca1c9b55', 'commits': [{'sha': 'd1b324fa1d02b42d55ea9d8454e9a271ef9a3829', 'author': {'email': 'actions@users.noreply.github.com', 'name': 'Automated'}, 'message': 'Latest data: Sun Aug 31 04:29:34 UTC 2025', 'distinct': True, 'url': 'https://api.github.com/repos/mbmontana785/my-data-robot/commits/d1b324fa1d02b42d55ea9d8454e9a271ef9a3829'}]}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487912', 'type': 'CreateEvent', 'actor': {'id': 160519209, 'login': 'S0rbito', 'display_login': 'S0rbito', 'gravatar_id': '', 'url': 'https://api.github.com/users/S0rbito', 'avatar_url': 'https://avatars.githubusercontent.com/u/160519209?'}, 'repo': {'id': 1047722359, 'name': 'S0rbito/Sorbito', 'url': 'https://api.github.com/repos/S0rbito/Sorbito'}, 'payload': {'ref': None, 'ref_type': 'repository', 'master_branch': 'main', 'description': None, 'pusher_type': 'user'}, 'public': True, 'created_at': '2025-08-31T04:29:36Z'}
# {'id': '54048487913', 'type': 'IssueCommentEvent', 'actor': {'id': 2107572, 'login': 'mattbaya', 'display_login': 'mattbaya', 'gravatar_id': '', 'url': 'https://api.github.com/users/mattbaya', 'avatar_url': 'https://avatars.githubusercontent.com/u/2107572?'}, 'repo': {'id': 1047602975, 'name': 'mattbaya/media-library-manager', 'url': 'https://api.github.com/repos/mattbaya/media-library-manager'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/mattbaya/media-library-manager/issues/28', 'repository_url': 'https://api.github.com/repos/mattbaya/media-library-manager', 'labels_url': 'https://api.github.com/repos/mattbaya/media-library-manager/issues/28/labels{/name}', 'comments_url': 'https://api.github.com/repos/mattbaya/media-library-manager/issues/28/comments', 'events_url': 'https://api.github.com/repos/mattbaya/media-library-manager/issues/28/events', 'html_url': 'https://github.com/mattbaya/media-library-manager/issues/28', 'id': 3369634550, 'node_id': 'I_kwDOPnEnH87I2Ir2', 'number': 28, 'title': 'Configuration and Environment Variable Security Issues', 'user': {'login': 'mattbaya', 'id': 2107572, 'node_id': 'MDQ6VXNlcjIxMDc1NzI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/2107572?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mattbaya', 'html_url': 'https://github.com/mattbaya', 'followers_url': 'https://api.github.com/users/mattbaya/followers', 'following_url': 'https://api.github.com/users/mattbaya/following{/other_user}', 'gists_url': 'https://api.github.com/users/mattbaya/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mattbaya/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mattbaya/subscriptions', 'organizations_url': 'https://api.github.com/users/mattbaya/orgs', 'repos_url': 'https://api.github.com/users/mattbaya/repos', 'events_url': 'https://api.github.com/users/mattbaya/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mattbaya/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'closed', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2025-08-31T00:51:52Z', 'updated_at': '2025-08-31T04:29:35Z', 'closed_at': '2025-08-31T04:29:35Z', 'author_association': 'OWNER', 'active_lock_reason': None, 'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0}, 'issue_dependencies_summary': {'blocked_by': 0, 'total_blocked_by': 0, 'blocking': 0, 'total_blocking': 0}, 'body': '**Security Issue: Insecure Configuration and Environment Handling**\n\n**Severity:** Medium\n\n**Description:** \nThe application lacks secure configuration management and environment variable handling.\n\n**Configuration Security Issues:**\n\n1. **Hardcoded Sensitive Paths:**\n   - Base path hardcoded: `/Volumes/media/Video`\n   - No environment variable support for configuration\n   - No config file validation\n\n2. **No Environment Isolation:**\n   - Inherits all parent environment variables\n   - No sanitization of environment\n   - Potential for environment variable injection\n\n3. **Missing Configuration Validation:**\n   - No validation of base_path parameter\n   - No check if directories are writable/readable\n   - No validation of external tool paths (ffmpeg, rclone)\n\n**Potential Environment Attacks:**\n\n1. **PATH Manipulation:**\n   ```bash\n   # Attacker modifies PATH to point to malicious binaries\n   export PATH="/tmp/evil:/Users/mjb9/.local/bin:/Users/mjb9/.opencode/bin:/Users/mjb9/.local/bin:/Users/mjb9/.npm-global/bin:/usr/local/anaconda3/bin:/usr/local/anaconda3/condabin:/usr/local/opt/php/bin:/usr/local/opt/whois/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/u ...
# {'id': '54048487907', 'type': 'WatchEvent', 'actor': {'id': 119543490, 'login': 'dadaz911', 'display_login': 'dadaz911', 'gravatar_id': '', 'url': 'https://api.github.com/users/dadaz911', 'avatar_url': 'https://avatars.githubusercontent.com/u/119543490?'}, 'repo': {'id': 332240585, 'name': 'niespodd/browser-fingerprinting', 'url': 'https://api.github.com/repos/niespodd/browser-fingerprinting'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-08-31T04:29:35Z'}
# {'id': '54048487905', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 1016605011, 'name': 'kalimbgn12/fan', 'url': 'https://api.github.com/repos/kalimbgn12/fan'}, 'payload': {'repository_id': 1016605011, 'push_id': 26484382522, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '34768624b6e7dbcf6e44f980fa231f06a6af9d9a', 'before': 'dec068268a0b419b388a2838777fb6e21f6c6bda', 'commits': [{'sha': '34768624b6e7dbcf6e44f980fa231f06a6af9d9a', 'author': {'email': 'kalimbgn12@users.noreply.github.com', 'name': 'kalimbgn12'}, 'message': 'Amend: 🛠 - Daily Commit #5 at 2025-08-31 04:29:34', 'distinct': True, 'url': 'https://api.github.com/repos/kalimbgn12/fan/commits/34768624b6e7dbcf6e44f980fa231f06a6af9d9a'}]}, 'public': True, 'created_at': '2025-08-31T04:29:35Z'}
# {'id': '54048487894', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 1035979889, 'name': 'CryoYohan/_gauto-cryo-ver', 'url': 'https://api.github.com/repos/CryoYohan/_gauto-cryo-ver'}, 'payload': {'repository_id': 1035979889, 'push_id': 26484382504, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'bfb5aea1b593deb1cac2e0b71db19c244e409dab', 'before': '317979095cb4aac6449b213f45a1526e62999d7a', 'commits': [{'sha': 'bfb5aea1b593deb1cac2e0b71db19c244e409dab', 'author': {'email': 'cyrilypil@gmail.com', 'name': 'CryoYohan'}, 'message': 'Automated commit #1204797', 'distinct': True, 'url': 'https://api.github.com/repos/CryoYohan/_gauto-cryo-ver/commits/bfb5aea1b593deb1cac2e0b71db19c244e409dab'}]}, 'public': True, 'created_at': '2025-08-31T04:29:35Z'}
# {'id': '54048487898', 'type': 'PushEvent', 'actor': {'id': 60399567, 'login': 'AMOmari', 'display_login': 'AMOmari', 'gravatar_id': '', 'url': 'https://api.github.com/users/AMOmari', 'avatar_url': 'https://avatars.githubusercontent.com/u/60399567?'}, 'repo': {'id': 781729861, 'name': 'AMOmari/Crpto_47', 'url': 'https://api.github.com/repos/AMOmari/Crpto_47'}, 'payload': {'repository_id': 781729861, 'push_id': 26484382511, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '48cf13335aeed7157d68144de6f39b49a1a6b061', 'before': '1c95e197dcec2292f89fd94ac8158b29d1874bc6', 'commits': [{'sha': '48cf13335aeed7157d68144de6f39b49a1a6b061', 'author': {'email': '60399567+AMOmari@users.noreply.github.com', 'name': 'Ahmad Al-Omari'}, 'message': 'Update HTML files', 'distinct': True, 'url': 'https://api.github.com/repos/AMOmari/Crpto_47/commits/48cf13335aeed7157d68144de6f39b49a1a6b061'}]}, 'public': True, 'created_at': '2025-08-31T04:29:35Z'}
# {'id': '54048487891', 'type': 'PushEvent', 'actor': {'id': 166895733, 'login': 'swa-runner-app[bot]', 'display_login': 'swa-runner-app', 'gravatar_id': '', 'url': 'https://api.github.com/users/swa-runner-app[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/166895733?'}, 'repo': {'id': 1047722331, 'name': 'static-web-apps-testing-org/swaeae5bbe1f7134b39aafc18d9c0c1142c', 'url': 'https://api.github.com/repos/static-web-apps-testing-org/swaeae5bbe1f7134b39aafc18d9c0c1142c'}, 'payload': {'repository_id': 1047722331, 'push_id': 26484382524, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '0738f642e015f57332a3d09ba180021447e20a48', 'before': '5a55e38a0231900ea93314a932a72e74789299f3', 'commits': [{'sha': '0738f642e015f57332a3d09ba180021447e20a48', 'author': {'email': '166895733+swa-runner-app[bot]@users.noreply.github.com', 'name': 'swa-runner-app[bot]'}, 'message': 'Writing file angular.json', 'distinct': True, 'url': 'https://api.github.com/repos/static-web-apps-testing-org/swaeae5bbe1f7134b39aafc18d9c0c1142c/commits/0738f642e015f57332a3d09ba180021447e20a48'}]}, 'public': True, 'created_at': '2025-08-31T04:29:35Z', 'org': {'id': 96167003, 'login': 'static-web-apps-testing-org', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/static-web-apps-testing-org', 'avatar_url': 'https://avatars.githubusercontent.com/u/96167003?'}}
# {'id': '54048487888', 'type': 'PushEvent', 'actor': {'id': 6509957, 'login': 'bateestah', 'display_login': 'bateestah', 'gravatar_id': '', 'url': 'https://api.github.com/users/bateestah', 'avatar_url': 'https://avatars.githubusercontent.com/u/6509957?'}, 'repo': {'id': 1035763466, 'name': 'bateestah/Truck_dispatch_sim', 'url': 'https://api.github.com/repos/bateestah/Truck_dispatch_sim'}, 'payload': {'repository_id': 1035763466, 'push_id': 26484382527, 'size': 2, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '882a6a05be7ba09db14eaa9aa65c4f69ed2269df', 'before': '8fd69dd8374c1131b1ac720ecb19c6c9e13ef7ac', 'commits': [{'sha': 'b9d8be73ea3ae79e18edf97207210886f8303380', 'author': {'email': 'bateestah@gmail.com', 'name': 'Alex'}, 'message': 'Allow assigning new drivers to HQ or properties', 'distinct': False, 'url': 'https://api.github.com/repos/bateestah/Truck_dispatch_sim/commits/b9d8be73ea3ae79e18edf97207210886f8303380'}, {'sha': '882a6a05be7ba09db14eaa9aa65c4f69ed2269df', 'author': {'email': 'bateestah@gmail.com', 'name': 'Alex'}, 'message': 'Merge pull request #34 from bateestah/codex/allow-custom-driver-assignment-location-3feo49\n\nAllow assigning newly hired drivers to HQ or properties', 'distinct': True, 'url': 'https://api.github.com/repos/bateestah/Truck_dispatch_sim/commits/882a6a05be7ba09db14eaa9aa65c4f69ed2269df'}]}, 'public': True, 'created_at': '2025-08-31T04:29:35Z'}
# {'id': '54048487875', 'type': 'PushEvent', 'actor': {'id': 58711734, 'login': 'manleysolutions', 'display_login': 'manleysolutions', 'gravatar_id': '', 'url': 'https://api.github.com/users/manleysolutions', 'avatar_url': 'https://avatars.githubusercontent.com/u/58711734?'}, 'repo': {'id': 1047696658, 'name': 'manleysolutions/DEMO_RTL_ATA_CSA', 'url': 'https://api.github.com/repos/manleysolutions/DEMO_RTL_ATA_CSA'}, 'payload': {'repository_id': 1047696658, 'push_id': 26484382509, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '48ae4af28a29940236eedda01f3bd55ec7284d35', 'before': 'd38731ee8b80c8cb0856a52c6bc35a4bc92cb766', 'commits': [{'sha': '48ae4af28a29940236eedda01f3bd55ec7284d35', 'author': {'email': 'smanley@manleysolutions.com', 'name': 'manleysolutions'}, 'message': '[CSA09] status update', 'distinct': True, 'url': 'https://api.github.com/repos/manleysolutions/DEMO_RTL_ATA_CSA/commits/48ae4af28a29940236eedda01f3bd55ec7284d35'}]}, 'public': True, 'created_at': '2025-08-31T04:29:35Z'}
# {'id': '54048487883', 'type': 'PushEvent', 'actor': {'id': 154775403, 'login': 'akmishra6441', 'display_login': 'akmishra6441', 'gravatar_id': '', 'url': 'https://api.github.com/users/akmishra6441', 'avatar_url': 'https://avatars.githubusercontent.com/u/154775403?'}, 'repo': {'id': 1046060611, 'name': 'akmishra6441/PDF_Editor', 'url': 'https://api.github.com/repos/akmishra6441/PDF_Editor'}, 'payload': {'repository_id': 1046060611, 'push_id': 26484382519, 'size': 2, 'distinct_size': 2, 'ref': 'refs/heads/main', 'head': '0f45455223aa84fc7a659f16e9befb0292be1728', 'before': '51ac5da77f9a67ee5ae388fae9fa98debde585f3', 'commits': [{'sha': '9f458d701ebe9fb07a4733359b830ed25c5e69f3', 'author': {'email': 'mishraabhishekh6441@gmail.com', 'name': 'Abhishekh Mishra'}, 'message': 'updates', 'distinct': True, 'url': 'https://api.github.com/repos/akmishra6441/PDF_Editor/commits/9f458d701ebe9fb07a4733359b830ed25c5e69f3'}, {'sha': '0f45455223aa84fc7a659f16e9befb0292be1728', 'author': {'email': 'mishraabhishekh6441@gmail.com', 'name': 'Abhishekh Mishra'}, 'message': 'Update index.html', 'distinct': True, 'url': 'https://api.github.com/repos/akmishra6441/PDF_Editor/commits/0f45455223aa84fc7a659f16e9befb0292be1728'}]}, 'public': True, 'created_at': '2025-08-31T04:29:35Z'}
# '54048487966'
