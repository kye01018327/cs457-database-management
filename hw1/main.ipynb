# %%
from bs4 import BeautifulSoup, SoupStrainer

# %%
with open(file='output.html', mode='r') as f:
    output = f.read()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
tags = SoupStrainer(name='td')
soup = BeautifulSoup(markup=output.text, features='html.parser', parse_only=tags)
print(soup.prettify())
# Out:
# <td>
#  8:30 a.m.
# </td>
# <td>
#  Tuesday/Thursday (TR)
# </td>
# <td>
#  8-10 a.m.
# </td>
# <td>
#  9 a.m.
# </td>
# <td>
#  Tuesday/Thursday (TR) or Thursday (R)
# </td>
# <td>
#  8-10 a.m.
# </td>
# <td>
#  11:30 a.m.
# </td>
# <td>
#  Tuesday/Thursday (TR)
# </td>
# <td>
#  10:15 a.m.-12:15 p.m.
# </td>
# <td>
#  12 p.m.
# </td>
# <td>
#  Tuesday/Thursday (TR)
# </td>
# <td>
#  10:15 a.m.-12:15 p.m.
# </td>
# <td>
#  1:30 p.m.
# </td>
# <td>
#  Thursday (R)
# </td>
# <td>
#  12:45-2:45 p.m.
# </td>
# <td>
#  3 p.m.
# </td>
# <td>
#  Tuesday/Thursday (TR) or Thursday (R)
# </td>
# <td>
#  3-5 p.m.
# </td>
# <td>
#  4:30 p.m.
# </td>
# <td>
#  Thursday (R)
# </td>
# <td>
#  5:30-7:30 p.m.
# </td>
# <td>
#  6 p.m.
# </td>
# <td>
#  Tuesday/Thursday (TR) or Thursday (R)
# </td>
# <td>
#  5:30-7:30 p.m.
# </td>
# <td>
#  7:30 p.m.
# </td>
# <td>
#  Thursday (R)
# </td>
# <td>
#  7:45-9:45 p.m.
# </td>
# <td>
#  9 p.m.
# </td>
# <td>
#  Tuesday/Thursday (TR)
# </td>
# <td>
# ...
